# %% [markdown]
# # Parameter Selection with preprocessing
#
# The key here is to avoid any leaking information of the data during the validation, means at validating our model the data used for validation should mimic the new data coming. Therefore splitting the data into train and test should be done before doing any preprocessing, knowledge extraction from data should be contained.

# %%
import mglearn
mglearn.plots.plot_improper_processing()
